# %%
import twitter
import json
CONSUMER_KEY = "40M3D2d9haFTmWiHUOqO3Wx7p"  
CONSUMER_SECRET = "FYdSd8Jcr5OmwQclQ1q1QwPLTwbVw3fX8Z35igJfqzmzLZp8d3"  
OAUTH_TOKEN = "1103068796036759552-iNLmsLjgYBODHZ1RcZBdsHG7g3d5wt"  
OAUTH_TOKEN_SECRET = "STv0EL4lsyamXzIYy6CZRE2wmml3toKuXQd5QDIV6nKtZ"  

api = twitter.Api(consumer_key=CONSUMER_KEY,
                      consumer_secret=CONSUMER_SECRET,
                      access_token_key=OAUTH_TOKEN,
                      access_token_secret=OAUTH_TOKEN_SECRET)

# %%
import pandas as pd

# %%
public_posts =[]
for i,x in enumerate(api.GetSearch(term='overwatch',count = 100)):
    public_tweet=dict()
    public_tweet['name'] = json.loads(str(x))['user']['name']
    public_tweet['id'] = json.loads(str(x))['id']
    public_tweet['followers'] = json.loads(str(x))['user']['followers_count']
    public_tweet['post'] = json.loads(str(x))['text']
    try: public_tweet['favourites'] = json.loads(str(x))['favorite_count']
    except: public_tweet['favourites'] = 0
    if         public_tweet['favourites'] == 0:
        try: public_tweet['favourites']=json.loads(str(x))['user']['favourites_count']
        except:public_tweet['favourites'] = 0
    try:public_tweet['retweet'] = json.loads(str(x))['retweet_count']
    except:public_tweet['retweet']=0
    public_tweet['hashtag'] = json.loads(str(x))['hashtags']
    public_tweet['statuses'] = json.loads(str(x))['user']['statuses_count']
    public_tweet['created_at'] = json.loads(str(x))['created_at']
    public_posts.append(public_tweet)

# %%
public_tweets_df = pd.DataFrame(public_posts)
public_tweets_df = public_tweets_df[['id','name','post','followers','created_at','retweet','favourites','statuses','hashtag']]
public_tweets_df
# Out:
#                      id                             name  \
# 0   1121112042432270337                        Overwatch
# 1   1121421162947457024                        Overwatch
# 2   1121130796348166144             San Francisco Shock⚡
# 3   1121659928270135300                        Tahaya ✌🏻
# 4   1121659815963418624                    PoochoPeaches
# 5   1121659799467282432                     Meli Marie ❤
# 6   1121659783696637952                 MJ Da 🦆Duckbear🐻
# 7   1121659769557639169                        Ponkereee
# 8   1121659720358457344                            🎃KAD🎃
# 9   1121659649185292288  Nat the Self Insert Smut Writer
# 10  1121659573033508864                          Eduardo
# 11  1121659565861294082                       tiger khan
# 12  1121659520978079744                           Dhafir
# 13  1121659496122609664                           Dhafir
# 14  1121659471057436672                        시체상태_UM유뮤
# 15  1121659411993202688                         Relusion
# 16  1121659386655412225                   Jun-Ka (F216F)
# 17  1121659374714273794                       MilkInhale
# 18  1121659358230630400                   overwatchpronz
# 19  1121659304803627008                   Amélie Lacroix
# 20  1121659259047907330                              パット
# 21  1121659231214551042                    martin molina
# 22  1121659215255224320                  princess 👑👁🌈🍩💎🔞
# 23  1121659213799772160                         God Yuna
# 24  1121659211396440066                           Dhafir
# 25  1121659187824447489                          star 🌸💘
# 26  1121659184972357633                       MilkInhale
# 27  1121659144656699392                           Lini 🔞
# 28  1121659071621296132                        Novaleesi
# 29  1121659047759863808                   🌸 Aurora1794 🌸
# ..                  ...                              ...
# 70  1121658076568809472                        higgo6969
# 71  1121658058684260354                            Zarek
# 72  1121658046575341569                         ごえもん@メイ専
# 73  1121658015491301378               Sav4ge #CGN [TeEm]
# 74  1121657975427330050             ☆ヒロ☆親豚会＆子豚会@DDON@MHW
# 75  1121657940228730882                     Diamond Dave
# 76  1121657936382611456                          Brendan
# 77  1121657876085268481               PumpkinSpiteLatte⚧
# 78  1121657802601054208                 𝒜𝒹𝓇𝒾𝑒𝓃 𝓌𝒾𝓉𝒽 𝓁𝓊𝓋✨
# 79  1121657776017514497                           Stinky
# 80  1121657769667387392                   JɆⱤɆ₥ł₳Ⱨ ₴₳ł₦₮
# 81  1121657766123192325                    Rifqi Fadholi
# 82  1121657702474604544                  Honey @ 🕯💀🔮🕸⚰🖤🕯
# 83  1121657698750124032                      rat bastard
# 84  1121657669197025280                   Unusual Person
# 85  1121657639975313408                        j1 2saucy
# 86  1121657608539033603                 [ENGR]CLaNCh_kei
# 87  1121657606710259713                      Jussi Halme
# 88  1121657604680208384                           K3MaMi
# 89  1121657576486105088               Chef_before_gaming
# 90  1121657548145184770      Map Of The Soul:  Persona🌸💜
# 91  1121657534928936961                       Bandy Gang
# 92  1121657527324725249                              랴류님
# 93  1121657520840294402                  princess 👑👁🌈🍩💎🔞
# 94  1121657455727919107                  aroundcoffeepot
# 95  1121657440053817346                   William Alonzo
# 96  1121657385603321859                  Sai da la turra
# 97  1121657304913338368                   Mr. Never Miss
# 98  1121657293123178496                        Dawndrell
# 99  1121657292636614659                     Sprite Pepsi
#
#                                                  post  followers  \
# 0   Assemble your ideas because there's work to be...    3249356
# 1   Witness players become heroes.\n\nThe Overwatc...    3249356
# 2   Are we using this new Overwatch Workshop right...     165614
# 3   Yasssss #mercy #skin #archives #overwatch #ove...         66
# 4   RT @gigideegee: my overwatch fancomic collecti...         35
# 5   RT @GhotiCzys: League of Legends Diana tee is ...        242
# 6   RT @xtyphoon__: hi i really want some more art...         93
# 7   RT @LEGDAYGaming: Overwatch: *Loads in Gibralt...         71
# 8   Which overwatch character do u think they'll k...        134
# 9   @desmondisalive @PlayOverwatch more like Overw...         51
# 10  RT @OverwatchTXT: The #Overwatch JoJo memes ar...        308
# 11  RT @EmperorLemon: me: *sees nasty, bitter, nuc...         84
# 12  RT @PleaseHelpFlo: Atlantic Mercy 🌊🧜🏻‍♀️ #Over...          5
# 13  RT @GrandpaBats: Surrender to my will... #over...          5
# 14  RT @Nez__________: 무력한 상태의 레예스가 보고 싶었쓰\n#Overw...        163
# 15  RT @OverwatchNaeri: Take the Skiing with Mei w...        950
# 16  Gamers' Mistresses ( 1/2 ) #FREETHEBOOTY by Mo...         58
# 17  RT @art_cerealex: ☠️ Deadlock McCree 🤠\nThis e...          4
# 18  RT @shiopill: D Va's new trim. 💖✂️\n(I've been...         47
# 19  ah yes, the founders of overwatch... Ana, Jack...       2146
# 20  RT @ciaraturnerart: The widow’s kiss 🕷 #widowm...         38
# 21  #Overwatch  #PS4share\n\nhttps://t.co/oekRXJxO...          1
# 22  technically it *can* reach it because i guess ...        268
# 23  RT @OverwatchES: ¡Reunid vuestras ideas porque...        690
# 24  RT @PlayOverwatch: Witness players become hero...          5
# 25  RT @HoshizoraOCE: Mercy mains on their way to ...        112
# 26  RT @lazysabin: Sombra in Street Wear 😉\n#Sombr...          4
# 27  RT @liangxing719: Hi guys! This is Pharah Dva ...         60
# 28  RT @ciaraturnerart: The widow’s kiss 🕷 #widowm...        120
# 29  RT @PlayOverwatch: Witness players become hero...         94
# ..                                                ...        ...
# 70                                @SypherPK Overwatch         16
# 71                                @SypherPK Overwatch          5
# 72  PlayStation 4からブロードキャストを始めました！ #PS4live (Overw...        132
# 73  RT @eddie_snacks: Getting into the real deal w...       2977
# 74  RT @IGN: BlizzCon 2019 is coming to Anaheim, C...        387
# 75  RT @eddie_snacks: Getting into the real deal w...        676
# 76  I can't escape silver in any competitive mode ...        254
# 77  RT @ow_pumpkinspite: #German Voicelines of #Ba...        332
# 78  @ImNateOfficial @TocataTV @SypherPK Overwatch ...        131
# 79  https://t.co/zZZrPfZkOV time to pop off as a c...         94
# 80  RT @eddie_snacks: Getting into the real deal w...        690
# 81  RT @IGN: BlizzCon 2019 is coming to Anaheim, C...         16
# 82  Wow I remember when drawing male faces scared ...         51
# 83  us, stupid: fix your game\n\noverwatch, big br...         35
# 84  こんなキャラOverwatchに居たっけ？って よく考えたらゲンジだわ笑 https://t...         11
# 85                                         Overwatch*        233
# 86                        @OVERWATCH_RYO @ken50129 俺w         12
# 87  RT @esportsfinland: FELin Overwatch Cupin poti...        557
# 88  RT @idlecum: And public today: #dVA and 76's n...         25
# 89  RT @eddie_snacks: Getting into the real deal w...       4977
# 90  RT @lualattae: i just really adore taehyung's ...        463
# 91  Made it so the EMP feels more "realistic" on B...          8
# 92  RT @OverwatchNaeri: Take the Skiing with Mei w...        361
# 93  i made a new overwatch game mode the code is 4...        268
# 94  RT @ciaraturnerart: The widow’s kiss 🕷 #widowm...         10
# 95  RT @IGN: BlizzCon 2019 is coming to Anaheim, C...        209
# 96  RT @Nez__________: 무력한 상태의 레예스가 보고 싶었쓰\n#Overw...        477
# 97  RT @Nez__________: 무력한 상태의 레예스가 보고 싶었쓰\n#Overw...          5
# 98  RT @KisumiMizkatt: Beachrat Junkrat with a cup...         19
# 99  RT @Nez__________: 무력한 상태의 레예스가 보고 싶었쓰\n#Overw...         31
#
#                         created_at  retweet  favourites  statuses  \
# 0   Wed Apr 24 18:01:54 +0000 2019     2116       10768    123856
# 1   Thu Apr 25 14:30:14 +0000 2019     2043       12252    123856
# 2   Wed Apr 24 19:16:26 +0000 2019      943        5709      5725
# 3   Fri Apr 26 06:19:00 +0000 2019        0           1       352
# 4   Fri Apr 26 06:18:34 +0000 2019       86       53778     27587
# 5   Fri Apr 26 06:18:30 +0000 2019        1        3465       699
# 6   Fri Apr 26 06:18:26 +0000 2019        5         883      1108
# 7   Fri Apr 26 06:18:23 +0000 2019      111         899        39
# 8   Fri Apr 26 06:18:11 +0000 2019        0       13586     11137
# 9   Fri Apr 26 06:17:54 +0000 2019        0         281      1432
# 10  Fri Apr 26 06:17:36 +0000 2019        7        9158      6938
# 11  Fri Apr 26 06:17:34 +0000 2019     2711        2706      3922
# 12  Fri Apr 26 06:17:23 +0000 2019      241          22        15
# 13  Fri Apr 26 06:17:17 +0000 2019     2395          22        15
# 14  Fri Apr 26 06:17:11 +0000 2019      105       18297    130677
# 15  Fri Apr 26 06:16:57 +0000 2019     1572        5446      5702
# 16  Fri Apr 26 06:16:51 +0000 2019        0        1601       621
# 17  Fri Apr 26 06:16:49 +0000 2019     1017        7896      5764
# 18  Fri Apr 26 06:16:45 +0000 2019       12         386      1617
# 19  Fri Apr 26 06:16:32 +0000 2019        0        1799     16865
# 20  Fri Apr 26 06:16:21 +0000 2019      975        3222       974
# 21  Fri Apr 26 06:16:14 +0000 2019        0           8        30
# 22  Fri Apr 26 06:16:10 +0000 2019        0        7469      2998
# 23  Fri Apr 26 06:16:10 +0000 2019       26       18815     19814
# 24  Fri Apr 26 06:16:10 +0000 2019     2043          22        15
# 25  Fri Apr 26 06:16:04 +0000 2019      267       38561     25597
# 26  Fri Apr 26 06:16:03 +0000 2019       39        7896      5764
# 27  Fri Apr 26 06:15:54 +0000 2019      152       23138      9447
# 28  Fri Apr 26 06:15:36 +0000 2019      975        4227      1131
# 29  Fri Apr 26 06:15:31 +0000 2019     2043        7767      4289
# ..                             ...      ...         ...       ...
# 70  Fri Apr 26 06:11:39 +0000 2019        0        2901        93
# 71  Fri Apr 26 06:11:35 +0000 2019        0         931       210
# 72  Fri Apr 26 06:11:32 +0000 2019        0        1311       573
# 73  Fri Apr 26 06:11:24 +0000 2019        4        1298     63342
# 74  Fri Apr 26 06:11:15 +0000 2019       20         978     57081
# 75  Fri Apr 26 06:11:07 +0000 2019        4         175     12434
# 76  Fri Apr 26 06:11:06 +0000 2019        0        4097      1998
# 77  Fri Apr 26 06:10:51 +0000 2019        1       27836     23809
# 78  Fri Apr 26 06:10:34 +0000 2019        0       21753      1481
# 79  Fri Apr 26 06:10:27 +0000 2019        0         684       431
# 80  Fri Apr 26 06:10:26 +0000 2019        4        8646     33207
# 81  Fri Apr 26 06:10:25 +0000 2019       20         465       954
# 82  Fri Apr 26 06:10:10 +0000 2019        0           1       867
# 83  Fri Apr 26 06:10:09 +0000 2019        0        1936      2935
# 84  Fri Apr 26 06:10:02 +0000 2019        0        1472      3395
# 85  Fri Apr 26 06:09:55 +0000 2019        0           1       164
# 86  Fri Apr 26 06:09:47 +0000 2019        0          13        48
# 87  Fri Apr 26 06:09:47 +0000 2019        3       12403      5675
# 88  Fri Apr 26 06:09:47 +0000 2019       14        3008      7009
# 89  Fri Apr 26 06:09:40 +0000 2019        4        1218    152916
# 90  Fri Apr 26 06:09:33 +0000 2019       12       62179     33924
# 91  Fri Apr 26 06:09:30 +0000 2019        0           0     11467
# 92  Fri Apr 26 06:09:28 +0000 2019     1572       20754     37458
# 93  Fri Apr 26 06:09:27 +0000 2019        0           1      2998
# 94  Fri Apr 26 06:09:11 +0000 2019      975        1971      1348
# 95  Fri Apr 26 06:09:07 +0000 2019       20       14156      6643
# 96  Fri Apr 26 06:08:54 +0000 2019      105        2896      9689
# 97  Fri Apr 26 06:08:35 +0000 2019      105         584        37
# 98  Fri Apr 26 06:08:32 +0000 2019       68       10638      5673
# 99  Fri Apr 26 06:08:32 +0000 2019      105       10654      7144
#
#                                               hashtag
# 0                                                  []
# 1                                                  []
# 2                                                  []
# 3   [{'text': 'mercy'}, {'text': 'skin'}, {'text':...
# 4                                                  []
# 5   [{'text': 'lol'}, {'text': 'leagueoflegends'},...
# 6                                                  []
# 7                                                  []
# 8                                                  []
# 9                                                  []
# 10                            [{'text': 'Overwatch'}]
# 11                                                 []
# 12         [{'text': 'Overwatch'}, {'text': 'Mercy'}]
# 13         [{'text': 'overwatch'}, {'text': 'Moira'}]
# 14                            [{'text': 'Overwatch'}]
# 15                                                 []
# 16                         [{'text': 'FREETHEBOOTY'}]
# 17  [{'text': 'Overwatch'}, {'text': 'OverwatchFan...
# 18                                                 []
# 19                                                 []
# 20    [{'text': 'widowmaker'}, {'text': 'overwatch'}]
# 21      [{'text': 'Overwatch'}, {'text': 'PS4share'}]
# 22                                                 []
# 23                                                 []
# 24                                                 []
# 25                                                 []
# 26        [{'text': 'Sombra'}, {'text': 'Overwatch'}]
# 27                                                 []
# 28    [{'text': 'widowmaker'}, {'text': 'overwatch'}]
# 29                                                 []
# ..                                                ...
# 70                                                 []
# 71                                                 []
# 72                              [{'text': 'PS4live'}]
# 73     [{'text': 'sadgamers'}, {'text': 'snackpack'}]
# 74                                                 []
# 75     [{'text': 'sadgamers'}, {'text': 'snackpack'}]
# 76                                                 []
# 77  [{'text': 'German'}, {'text': 'Baptiste'}, {'t...
# 78                                                 []
# 79                                                 []
# 80     [{'text': 'sadgamers'}, {'text': 'snackpack'}]
# 81                                                 []
# 82                          [{'text': 'FaceYourArt'}]
# 83                                                 []
# 84                                                 []
# 85                                                 []
# 86                                                 []
# 87                                                 []
# 88  [{'text': 'dVA'}, {'text': '오버워치'}, {'text': '...
# 89     [{'text': 'sadgamers'}, {'text': 'snackpack'}]
# 90                                                 []
# 91                                                 []
# 92                                                 []
# 93                                                 []
# 94    [{'text': 'widowmaker'}, {'text': 'overwatch'}]
# 95                                                 []
# 96                            [{'text': 'Overwatch'}]
# 97                            [{'text': 'Overwatch'}]
# 98  [{'text': 'Overwatch'}, {'text': 'OverwatchFan...
# 99                            [{'text': 'Overwatch'}]
#
# [100 rows x 9 columns]

# %%
public_tweets_df.to_csv("overwatch",index=False,sep=',')

# %%
SCREEN_NAME="playoverwatch"
results = api.GetUserTimeline(screen_name=SCREEN_NAME,count = 100)

posts =[]
favourites =[]
retweets = []
time = []
user_id = []
name = []
followers = []
hashtags = []

for each in results:
    status = json.loads(str(each))
    posts.append(status['text'])
    try:
        favourites.append(status['favorite_count'])
    except:
        favourites.append(status['retweeted_status']['favorite_count'])
    
    try: retweets.append(status['retweet_count'])
    except: retweets.append('0')
    time.append(status['created_at'])
    user_id.append(status['user']['id'])
    followers.append(status['user']['followers_count'])
    name.append(status['user']['name'])
    try:
        hashtags.append(status['hashtags'][0]['text'])
    except:
        hashtags.append(status['hashtags'])

print([s for s in posts])
# Out:
# ["@lolmaowtfXD @iiweirdness @officialvalkia @soliteary We're all members of the same community. https://t.co/BiIsTIroeX", '@HellPharah https://t.co/Ubn9CD1S9m', '@GZCharge We all do.', '@catgirlneko @ddaenglalisa https://t.co/sYwMIGwWec', "RT @overwatchleague: Gear up for #OWL2019 All Stars with legendary skins for 200 tokens each!\n\nHere's the All-Star action going down:\nTalen…", '&gt; Accessing archived file...\n\nDecryption status: COMPLETE\n\n📂 STORM RISING INTEL EXAMINATION – MAXIMILIEN https://t.co/IlFyuhVF5D', '@byeless2 Overwatch loves you.', '@yonatanbait Snag your flags and face paint!', 'Witness players become heroes.\n\nThe Overwatch World Cup is back! ￼￼\n\n 🌎🏆 https://t.co/iE9zg3Qbzi https://t.co/7upvzwvTik', "@Blizzard_Ent Let's get this party STARTED!! 🐸🎶 https://t.co/1JWswjcgow", 'RT @Blizzard_Ent: BlizzCon 2019 will be November 1-2 at the Anaheim Convention Center!  New this year: BlizzCon Pregame Festivities, new ti…', 'RT @DanielFenner: The new workshop feature in @PlayOverwatch is INCREDIBLE, there are going to be so many amazing custom games made with it…', '@Top2Bottom2345 🤔🤔🤔🤔🤔🤔😏', "@MMrby69 It's currently on the PTR.", '@coralines Overwatch loves you.', 'Roll up your sleeves and show us a marvel of engineering!\n\nIntroducing the Overwatch Workshop—create a Script to ad… https://t.co/tKY7SfTV0x', "@ChengduHunters Here's a guide, practice makes perfect! https://t.co/fT2939blDJ", '@ItsTripleAye https://t.co/Pe2Yx6detN', '@TorontoDefiant https://t.co/2wLQMkcA4W', '@ZekZebZab Read up on more info here: https://t.co/fT2939blDJ', '@kristinaspaige Enable captions fam 😉', "Assemble your ideas because there's work to be done! 💡🔨 \n\nGame Director Jeff Kaplan lays the groundwork on Overwatc… https://t.co/nVq5VxI1nk", "RT @art_cerealex: ☠️ Deadlock McCree 🤠\nThis event's skins are so good!!\n#Overwatch #OverwatchFanart https://t.co/0JttKDyBRa", 'RT @fayren: Is this really necessary? https://t.co/dnvFXW04DL', '@Ayana_Mudou https://t.co/BjFGQm8d9a', "@Ashe____0 We're humbled by our community. Thank you!", '@GVBBlE 👍', 'Never accept the world as it appears to be, dare to see it for what it could be.\n\nHappy #EarthDay, heroes. https://t.co/POOnPBEi5T', '@GrandpaBats Most impressive.', 'RT @GrandpaBats: Surrender to my will... #overwatch #Moira https://t.co/aKhdpmAu84', '@TheMasterKrook 😉 https://t.co/aulfr1nA5j', '@RapidRapidash We appreciate your feedback.', 'Don’t let him escape. 🤖 Assemble your strike team and join the chase! \n\nPlay Overwatch FREE through April 23 on PC,… https://t.co/wia7yMOts6', 'RT @anhdangerous: Ashe Socialite weapon concept I made for the Overwatch Storm Rising event https://t.co/8ok9Z6RXqX', "RT @NatesonOfficial: https://t.co/LWuJSuN9l7 Let's get some SWEET games in today. Live right now!! @PlayOverwatch https://t.co/INIWHoH4dC", '@Stylosa Indeed, it is Escort, not Assault.', '@LAGladiators Correct. It is an Escort map! Apologies for the confusion.', 'Captivating oceanfront. 🏖️ \nUnbelievable artistry. 🎨 \nBeaming sunshine. ☀️ \nAwesome music. 🎺 \n\nWhat are you waiting… https://t.co/fIioRkuBWJ', '@beybarro https://t.co/hJQgLFSBSu', "@TheMasterKrook We're glad you dig it. 👍", 'This apparel is no longer confidential! \n\nReveal your allegiance with new Archives Gear available in the… https://t.co/UNCLmWRq9H', 'RT @macchama674: ハイローラーハモンドとネズミジャンクラと科学者モイラ🐹🐭⚗️\n#Overwatch #オーバーウォッチ #OWアート https://t.co/35RKnH0Gzv', 'RT @KisumiMizkatt: Thank you Blizzard, I love him 💕💕💕\n#Overwatch #OverwatchFanart https://t.co/FeSsihYjVs', "@bones_ablaze We'd recommend you completely exit the application and restart the game.", '@literalgarbagio https://t.co/iKCVj0FtdS', '@anarchpls https://t.co/XaZzVNSNpa', '⚠️ EMERGENCY ALERT \n\nHurricane Warning in this area until 5.6.19. Check local media and Jeff Kaplan for an update o… https://t.co/W2lkeqqsQH', 'RT @ohnickel: 🚨 LIVE 🚨 FROM BLIZZARD HQ! Playing The New @PlayOverwatch Event W/ Special Guest Jeff Kaplan! \n\nWatch here: https://t.co/HAuu…', '@SkylarStorm ...

# %%
import pandas as pd
df_1 = pd.DataFrame(data = name, columns = ['Name'])
df_1['User_id'] = user_id
df_1['Followers'] = followers
df_1['Post'] = posts
df_1['Hashtags'] = hashtags
df_1['Posted_time'] = time
df_1['Favourites'] = favourites
df_1['retweets'] = retweets

# %%
df_1
# Out:
#          Name     User_id  Followers  \
# 0   Overwatch  2420931980    3249356
# 1   Overwatch  2420931980    3249356
# 2   Overwatch  2420931980    3249356
# 3   Overwatch  2420931980    3249356
# 4   Overwatch  2420931980    3249356
# 5   Overwatch  2420931980    3249356
# 6   Overwatch  2420931980    3249356
# 7   Overwatch  2420931980    3249356
# 8   Overwatch  2420931980    3249356
# 9   Overwatch  2420931980    3249356
# 10  Overwatch  2420931980    3249356
# 11  Overwatch  2420931980    3249356
# 12  Overwatch  2420931980    3249356
# 13  Overwatch  2420931980    3249356
# 14  Overwatch  2420931980    3249356
# 15  Overwatch  2420931980    3249356
# 16  Overwatch  2420931980    3249356
# 17  Overwatch  2420931980    3249356
# 18  Overwatch  2420931980    3249356
# 19  Overwatch  2420931980    3249356
# 20  Overwatch  2420931980    3249356
# 21  Overwatch  2420931980    3249356
# 22  Overwatch  2420931980    3249356
# 23  Overwatch  2420931980    3249356
# 24  Overwatch  2420931980    3249356
# 25  Overwatch  2420931980    3249356
# 26  Overwatch  2420931980    3249356
# 27  Overwatch  2420931980    3249356
# 28  Overwatch  2420931980    3249356
# 29  Overwatch  2420931980    3249356
# ..        ...         ...        ...
# 70  Overwatch  2420931980    3249356
# 71  Overwatch  2420931980    3249356
# 72  Overwatch  2420931980    3249356
# 73  Overwatch  2420931980    3249356
# 74  Overwatch  2420931980    3249356
# 75  Overwatch  2420931980    3249356
# 76  Overwatch  2420931980    3249356
# 77  Overwatch  2420931980    3249356
# 78  Overwatch  2420931980    3249356
# 79  Overwatch  2420931980    3249356
# 80  Overwatch  2420931980    3249356
# 81  Overwatch  2420931980    3249356
# 82  Overwatch  2420931980    3249356
# 83  Overwatch  2420931980    3249356
# 84  Overwatch  2420931980    3249356
# 85  Overwatch  2420931980    3249356
# 86  Overwatch  2420931980    3249356
# 87  Overwatch  2420931980    3249356
# 88  Overwatch  2420931980    3249356
# 89  Overwatch  2420931980    3249356
# 90  Overwatch  2420931980    3249356
# 91  Overwatch  2420931980    3249356
# 92  Overwatch  2420931980    3249356
# 93  Overwatch  2420931980    3249356
# 94  Overwatch  2420931980    3249356
# 95  Overwatch  2420931980    3249356
# 96  Overwatch  2420931980    3249356
# 97  Overwatch  2420931980    3249356
# 98  Overwatch  2420931980    3249356
# 99  Overwatch  2420931980    3249356
#
#                                                  Post      Hashtags  \
# 0   @lolmaowtfXD @iiweirdness @officialvalkia @sol...            []
# 1                 @HellPharah https://t.co/Ubn9CD1S9m            []
# 2                                @GZCharge We all do.            []
# 3   @catgirlneko @ddaenglalisa https://t.co/sYwMIG...            []
# 4   RT @overwatchleague: Gear up for #OWL2019 All ...       OWL2019
# 5   &gt; Accessing archived file...\n\nDecryption ...            []
# 6                      @byeless2 Overwatch loves you.            []
# 7        @yonatanbait Snag your flags and face paint!            []
# 8   Witness players become heroes.\n\nThe Overwatc...            []
# 9   @Blizzard_Ent Let's get this party STARTED!! 🐸...            []
# 10  RT @Blizzard_Ent: BlizzCon 2019 will be Novemb...            []
# 11  RT @DanielFenner: The new workshop feature in ...            []
# 12                            @Top2Bottom2345 🤔🤔🤔🤔🤔🤔😏            []
# 13                @MMrby69 It's currently on the PTR.            []
# 14                    @coralines Overwatch loves you.            []
# 15  Roll up your sleeves and show us a marvel of e...            []
# 16  @ChengduHunters Here's a guide, practice makes...            []
# 17              @ItsTripleAye https://t.co/Pe2Yx6detN            []
# 18            @TorontoDefiant https://t.co/2wLQMkcA4W            []
# 19  @ZekZebZab Read up on more info here: https://...            []
# 20              @kristinaspaige Enable captions fam 😉            []
# 21  Assemble your ideas because there's work to be...            []
# 22  RT @art_cerealex: ☠️ Deadlock McCree 🤠\nThis e...     Overwatch
# 23  RT @fayren: Is this really necessary? https://...            []
# 24               @Ayana_Mudou https://t.co/BjFGQm8d9a            []
# 25  @Ashe____0 We're humbled by our community. Tha...            []
# 26                                          @GVBBlE 👍            []
# 27  Never accept the world as it appears to be, da...      EarthDay
# 28                      @GrandpaBats Most impressive.            []
# 29  RT @GrandpaBats: Surrender to my will... #over...     overwatch
# ..                                                ...           ...
# 70               @IPreferChef https://t.co/HxkdZVK9wX            []
# 71  Save the medals, I've had my fill. 🎖️\n\nComme...            []
# 72                           @Doctor_Yiggles Get. It.            []
# 73               @FoxyLover115 Indeed, it is an Epic.            []
# 74  @PlayStation You've gotta risk it for the bisc...            []
# 75                  @AdelCODz https://t.co/3WAvM23QPB            []
# 76  RT @PlayStation: Roll with style 🕶️\n\nBehold ...            []
# 77  RT @avedral: Soo... I drew the new #Moira skin...         Moira
# 78               @heaIsIuto3o https://t.co/p9W8xNJ3Iz            []
# 79                    @SirKuno We're glad you dig it.            []
# 80                                       @VonHollde 😂            []
# 81                    @Frosty_U_ Overwatch loves you.            []
# 82  @LolaTempest We'll pass along the kind words. ...            []
# 83  Saddle up with the infamous outlaw gang. 🌵\n\n...            []
# 84          @AngelosFrag Thank you for your feedback!            []
# 85  Spring for these deals!\n  \nDash to the #Bliz...  BlizzardGear
# 86                  @SilenS99 https://t.co/1Hn7Ndd2gu            []
# 87                @DallasFuel https://t.co/2crxX3REBB            []
# 88  RT @maro_chick: 모두 여길 봐주세요~ https://t.co/oaP6K...            []
# 89                 @gamewatchtoday It was inevitable.            []
# 90     @forestsknight What an interesting hypothesis.            []
# 91                      @TheMasterKrook Much obliged.            []
# 92                           @SilenS99 Predictable. 🧪            []
# 93            @MoiraDeodorant https://t.co/18d8gO9beO            []
# 94  Science will reveal the truth.\n\nFind your el...            []
# 95  @TheMasterKrook @Xbox Alright Krook, you win t...            []
# 96  @Xbox Heroes, come out and play.\n\nStart clow...            []
# 97  RT @Xbox: It’s a perfect day for some mayhem.\...            []
# 98  @FortniteTapohi I got you. https://t.co/scTHec...            []
# 99               @transpaladin You're most welcome. 👍            []
#
#                        Posted_time  Favourites retweets
# 0   Thu Apr 25 23:22:29 +0000 2019           8        1
# 1   Thu Apr 25 23:20:37 +0000 2019          43        1
# 2   Thu Apr 25 23:17:38 +0000 2019         315        6
# 3   Thu Apr 25 23:16:48 +0000 2019         132        3
# 4   Thu Apr 25 21:38:36 +0000 2019        9126     2711
# 5   Thu Apr 25 20:00:00 +0000 2019       16289     3765
# 6   Thu Apr 25 14:46:41 +0000 2019         137        1
# 7   Thu Apr 25 14:45:28 +0000 2019          58        0
# 8   Thu Apr 25 14:30:14 +0000 2019       12253     2043
# 9   Thu Apr 25 14:23:52 +0000 2019        1032       48
# 10  Thu Apr 25 14:21:57 +0000 2019        3463      803
# 11  Thu Apr 25 00:03:45 +0000 2019       14257     3251
# 12  Wed Apr 24 22:54:52 +0000 2019         278        3
# 13  Wed Apr 24 22:03:24 +0000 2019         126        3
# 14  Wed Apr 24 22:02:46 +0000 2019          34        2
# 15  Wed Apr 24 22:00:38 +0000 2019       10905     1905
# 16  Wed Apr 24 18:19:17 +0000 2019         474       47
# 17  Wed Apr 24 18:18:12 +0000 2019          30        2
# 18  Wed Apr 24 18:17:25 +0000 2019         950       16
# 19  Wed Apr 24 18:16:24 +0000 2019          43        5
# 20  Wed Apr 24 18:15:28 +0000 2019         208        1
# 21  Wed Apr 24 18:01:54 +0000 2019       10768     2116
# 22  Wed Apr 24 00:56:42 +0000 2019        5196     1017
# 23  Tue Apr 23 16:32:29 +0000 2019       19556     4722
# 24  Tue Apr 23 00:12:31 +0000 2019         133        1
# 25  Mon Apr 22 20:09:25 +0000 2019          85        0
# 26  Mon Apr 22 20:03:51 +0000 2019         152        1
# 27  Mon Apr 22 20:02:04 +0000 2019       34130     6504
# 28  Mon Apr 22 17:42:09 +0000 2019         188        3
# 29  Mon Apr 22 17:41:47 +0000 2019        9383     2395
# ..                             ...         ...      ...
# 70  Sat Apr 13 16:05:26 +0000 2019        1156       18
# 71  Sat Apr 13 16:00:00 +0000 2019       49554    11863
# 72  Fri Apr 12 20:51:35 +0000 2019         127        2
# 73  Fri Apr 12 20:51:08 +0000 2019         184        0
# 74  Fri Apr 12 20:44:16 +0000 2019        1256      110
# 75  Fri Apr 12 20:41:31 +0000 2019         597       31
# 76  Fri Apr 12 20:33:07 +0000 2019       18925     4560
# 77  Fri Apr 12 17:18:28 +0000 2019        7030     1092
# 78  Fri Apr 12 16:15:00 +0000 2019        4770     1161
# 79  Fri Apr 12 16:09:34 +0000 2019         127        0
# 80  Fri Apr 12 16:06:08 +0000 2019         305        3
# 81  Fri Apr 12 16:04:38 +0000 2019         100        1
# 82  Fri Apr 12 16:04:28 +0000 2019         204        1
# 83  Fri Apr 12 16:00:00 +0000 2019       40656    10166
# 84  Thu Apr 11 21:02:45 +0000 2019          20        0
# 85  Thu Apr 11 20:52:20 +0000 2019        2684      262
# 86  Thu Apr 11 20:41:53 +0000 2019         156        1
# 87  Thu Apr 11 20:41:28 +0000 2019         483       13
# 88  Thu Apr 11 20:25:03 +0000 2019       20014     5070
# 89  Thu Apr 11 17:08:05 +0000 2019         211        4
# 90  Thu Apr 11 17:06:22 +0000 2019         244        4
# 91  Thu Apr 11 17:01:38 +0000 2019         199        1
# 92  Thu Apr 11 16:59:39 +0000 2019         194        1
# 93  Thu Apr 11 16:46:03 +0000 2019         410        8
# 94  Thu Apr 11 16:00:00 +0000 2019       38236     9842
# 95  Thu Apr 11 06:59:29 +0000 2019         542        7
# 96  Thu Apr 11 00:07:48 +0000 2019        1613      160
# 97  Thu Apr 11 00:02:22 +0000 2019       15704     3433
# 98  Wed Apr 10 16:20:51 +0000 2019         233        1
# 99  Wed Apr 10 16:19:42 +0000 2019          95        1
#
# [100 rows x 8 columns]

# %%
df_1.to_csv("overwatchpage",index=False,sep=',')

# %%
retweets.append(status['retweet_count'])
